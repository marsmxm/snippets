// %%
:dep ascii_tree = {version = "0.1.1"}

// %%
use std::fmt::Display;
use std::rc::{Rc, Weak};
use std::cell::RefCell;
use ascii_tree::{Tree, write_tree}

pub struct BinaryTree<T: Display + PartialOrd> {
    root: Link<T>,
}

type Link<T: Display + PartialOrd> = Option<Rc<RefCell<Node<T>>>>;

pub struct Node<T: Display + PartialOrd> {
    key: T,
    parent: Weak<Node<T>>,
    left: Link<T>,
    right: Link<T>,
}

impl<T: Display + PartialOrd> Node<T> {
    fn new(key: T) -> Self {
        Node {
            key,
            parent: Weak::new(),
            left: None,
            right: None,
        }
    }

    fn to_ascii_tree(&self) -> Tree {
        let left_tree = self.left.as_ref().map(|node| node.borrow().to_ascii_tree());
        let right_tree = self.right.as_ref().map(|node| node.borrow().to_ascii_tree());
        
        let mut children = Vec::new();
        if left_tree.is_some() {
            children.push(left_tree.unwrap());
        }
        if right_tree.is_some() {
            children.push(right_tree.unwrap());
        }
        
        Tree::Node(self.key.to_string(), children)
    }
}

impl<T: Display + PartialOrd> BinaryTree<T> {
    pub fn empty() -> Self {
        BinaryTree {
            root: None,
        }
    }

    pub fn new(root: Node<T>) -> Self {
        BinaryTree {
            root: Some(Rc::new(RefCell::new(root))),
        }
    }

    pub fn insert(&mut self, k: T) {
        let mut new_node = Rc::new(RefCell::new(Node::new(k)));

        match self.root.as_ref() {
            None => {
                self.root  = Some(new_node);
            }
            Some(_) => {
                let mut cursor = &self.root;
                let mut parent = &None;
        
                while let Some(node) = cursor.as_ref() {
                    parent = cursor;

                    if new_node.key < node.key {
                        cursor = &node.left;
                    } else {
                        cursor = &node.right;
                    }
                }

                if let Some(parent_rc) = parent.as_ref() {
                    new_node.parent = Rc::downgrade(parent_rc);
                    if new_node.key < parent_rc.key {
                        parent_rc.left = Some(new_node);
                    } else {
                        parent_rc.right = Some(new_node);
                    }
                } else {
                    panic!("none parent");
                }
                
            }
        }
        
    }

    pub fn walk(&self) {
        fn link_walk<T: Display + PartialOrd>(link: &Link<T>) {
            if let Some(node) = link.as_ref() {
                link_walk(&node.left);
                println!("{}", node.borrow().key);
                link_walk(&node.right);
            }
        }

        link_walk(&self.root);
    }

    pub fn search(&self, k: T) -> Option<&Node<T>> {
        fn search_link<T: Display + PartialOrd>(link: &Link<T>, k: T) -> Option<&Node<T>> {
            if let Some(node) = link.as_ref() {
                if node.key == k {
                    return Some(&node);
                } else if k < node.key {
                    return search_link(&node.left, k);
                } else {
                    return search_link(&node.right, k);
                }
            } else {
                return None;
            }
        }

        search_link(&self.root, k)
    }

    pub fn search_iter(&self, k: T) -> Option<&Node<T>> {
        let mut cursor = &self.root;
        while let Some(node) = cursor.as_ref() {
            if k == node.key {
                return Some(&node);
            } else if k < node.key {
                cursor = &node.left;
            } else {
                cursor = &node.right;
            }
        }

        return None;
    }

    pub fn minimum(&self) -> Option<&Node<T>> {
        let mut cursor = &self.root;

        while let Some(node) = cursor.as_ref() {
            cursor = &node.left;
        }

        cursor.as_ref().map(|node_box| node_box.as_ref())
    }

    pub fn maximum(&self) -> Option<&Node<T>> {
        let mut cursor = &self.root;

        while let Some(node) = cursor.as_ref() {
            cursor = &node.right;
        }

        cursor.as_ref().map(|node_box| node_box.as_ref())
    }

    pub fn print(&self) {
        let none_node = Tree::Leaf(vec![String::from("none")]);
        let ascii_tree = self.root.as_ref().map_or(none_node, |node| node.to_ascii_tree());
        let mut output = String::new();
        write_tree(&mut output, &ascii_tree);
        println!("{}", output);
    }
}
// Out:
// [E0599] Error: no method named `to_ascii_tree` found for reference `&Rc<RefCell<Node<T>>>` in the current scope
//     ╭─[command_18:1:1]
//     │
//  30 │         let left_tree = self.left.as_ref().map(|node| node.to_ascii_tree());
//     │                                                            ──────┬──────
//     │                                                                  ╰──────── method not found in `&Rc<RefCell<Node<T>>>`
// ────╯
// [E0599] Error: no method named `to_ascii_tree` found for reference `&Rc<RefCell<Node<T>>>` in the current scope
//     ╭─[command_18:1:1]
//     │
//  31 │         let right_tree = self.right.as_ref().map(|node| node.to_ascii_tree());
//     │                                                              ──────┬──────
//     │                                                                    ╰──────── method not found in `&Rc<RefCell<Node<T>>>`
// ────╯
// [E0308] Error: mismatched types
//     ╭─[command_18:1:1]
//     │
//  54 │             root: Some(Rc::new(root)),
//     │                        ───┬─── ──┬─│
//     │                           ╰────────── arguments to this function are incorrect
//     │                                  │ │
//     │                                  ╰─── expected `RefCell<Node<T>>`, found `Node<T>`
//     │                                    │
//     │                                    ╰─ help: call `Into::into` on this expression to convert `Node<T>` into `RefCell<Node<T>>`: `.into()`
//     │
//     │ Note: note: associated function defined here
// ────╯
// [E0308] Error: mismatched types
//     ╭─[command_18:1:1]
//     │
//  63 │                 self.root  = Some(new_node);
//     │                              ──┬─ ────┬───
//     │                                ╰──────────── arguments to this enum variant are incorrect
//     │                                       │
//     │                                       ╰───── expected `Rc<RefCell<Node<T>>>`, found `Rc<Node<T>>`
//     │
//     │ Note: note: tuple variant defined here
// ────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  72 │                     if new_node.key < node.key {
//     │                                            ─┬─
//     │                                             ╰─── unknown field
// ────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  73 │                         cursor = &node.left;
//     │                                        ──┬─
//     │                                          ╰─── unknown field
// ────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  75 │                         cursor = &node.right;
//     │                                        ──┬──
//     │                                          ╰──── unknown field
// ────╯
// [E0308] Error: mismatched types
//     ╭─[command_18:1:1]
//     │
//  80 │                     new_node.parent = Rc::downgrade(parent_rc);
//     │                                       ──────┬────── ────┬────
//     │                                             ╰────────────────── arguments to this function are incorrect
//     │                                                         │
//     │                                                         ╰────── expected `&Rc<Node<T>>`, found `&Rc<RefCell<Node<T>>>`
//     │
//     │ Note: note: associated function defined here
// ────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  81 │                     if new_node.key < parent_rc.key {
//     │                                                 ─┬─
//     │                                                  ╰─── unknown field
// ────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  82 │                         parent_rc.left = Some(new_node);
//     │                                   ──┬─
//     │                                     ╰─── unknown field
// ────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  84 │                         parent_rc.right = Some(new_node);
//     │                                   ──┬──
//     │                                     ╰──── unknown field
// ────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  98 │                 link_walk(&node.left);
//     │                                 ──┬─
//     │                                   ╰─── unknown field
// ────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//     ╭─[command_18:1:1]
//     │
//  99 │                 println!("{}", node.key);
//     │                                     ─┬─
//     │                                      ╰─── unknown field
// ────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  100 │                 link_walk(&node.right);
//      │                                 ──┬──
//      │                                   ╰──── unknown field
// ─────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  110 │                 if node.key == k {
//      │                         ─┬─
//      │                          ╰─── unknown field
// ─────╯
// [E0308] Error: mismatched types
//      ╭─[command_18:1:1]
//      │
//  111 │                     return Some(&node);
//      │                            ──┬─ ──┬──
//      │                              ╰───────── arguments to this enum variant are incorrect
//      │                                   │
//      │                                   ╰──── expected `&Node<T>`, found `&&Rc<RefCell<Node<T>>>`
//      │
//      │ Note: note: tuple variant defined here
// ─────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  112 │                 } else if k < node.key {
//      │                                    ─┬─
//      │                                     ╰─── unknown field
// ─────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  113 │                     return search_link(&node.left, k);
//      │                                              ──┬─
//      │                                                ╰─── unknown field
// ─────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  115 │                     return search_link(&node.right, k);
//      │                                              ──┬──
//      │                                                ╰──── unknown field
// ─────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  128 │             if k == node.key {
//      │                          ─┬─
//      │                           ╰─── unknown field
// ─────╯
// [E0308] Error: mismatched types
//      ╭─[command_18:1:1]
//      │
//  129 │                 return Some(&node);
//      │                        ──┬─ ──┬──
//      │                          ╰───────── arguments to this enum variant are incorrect
//      │                               │
//      │                               ╰──── expected `&Node<T>`, found `&&Rc<RefCell<Node<T>>>`
//      │
//      │ Note: note: tuple variant defined here
// ─────╯
// [E0609] Error: no field `key` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  130 │             } else if k < node.key {
//      │                                ─┬─
//      │                                 ╰─── unknown field
// ─────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  131 │                 cursor = &node.left;
//      │                                ──┬─
//      │                                  ╰─── unknown field
// ─────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  133 │                 cursor = &node.right;
//      │                                ──┬──
//      │                                  ╰──── unknown field
// ─────╯
// [E0609] Error: no field `left` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  144 │             cursor = &node.left;
//      │                            ──┬─
//      │                              ╰─── unknown field
// ─────╯
// [E0308] Error: mismatched types
//      ╭─[command_18:1:1]
//      │
//  140 │     pub fn minimum(&self) -> Option<&Node<T>> {
//      │                              ────────┬───────
//      │                                      ╰───────── expected `Option<&Node<T>>` because of return type
//      │
//  147 │         cursor.as_ref().map(|node_box| node_box.as_ref())
//      │         ────────────────────────┬────────────────────────
//      │                                 ╰────────────────────────── expected `Option<&Node<T>>`, found `Option<&RefCell<Node<T>>>`
// ─────╯
// [E0609] Error: no field `right` on type `&Rc<RefCell<Node<T>>>`
//      ╭─[command_18:1:1]
//      │
//  154 │             cursor = &node.right;
//      │                            ──┬──
//      │                              ╰──── unknown field
// ─────╯
// [E0308] Error: mismatched types
//      ╭─[command_18:1:1]
//      │
//  150 │     pub fn maximum(&self) -> Option<&Node<T>> {
//      │                              ────────┬───────
//      │                                      ╰───────── expected `Option<&Node<T>>` because of return type
//      │
//  157 │         cursor.as_ref().map(|node_box| node_box.as_ref())
//      │         ────────────────────────┬────────────────────────
//      │                                 ╰────────────────────────── expected `Option<&Node<T>>`, found `Option<&RefCell<Node<T>>>`
// ─────╯
// [E0599] Error: no method named `to_ascii_tree` found for reference `&Rc<RefCell<Node<T>>>` in the current scope
//      ╭─[command_18:1:1]
//      │
//  162 │         let ascii_tree = self.root.as_ref().map_or(none_node, |node| node.to_ascii_tree());
//      │                                                                           ──────┬──────
//      │                                                                                 ╰──────── method not found in `&Rc<RefCell<Node<T>>>`
// ─────╯
