// %%
:dep ascii_tree = {version = "0.1.1"}

// %%
use std::fmt::Display;
use std::rc::{Rc, Weak};
use std::cell::{RefCell, Ref};
use ascii_tree::{Tree, write_tree}

pub struct BinaryTree<T: Display + PartialOrd> {
    root: Link<T>,
}

type Link<T: Display + PartialOrd> = Option<Rc<RefCell<Node<T>>>>;

pub struct Node<T: Display + PartialOrd> {
    key: T,
    parent: Weak<Node<T>>,
    left: Link<T>,
    right: Link<T>,
}

impl<T: Display + PartialOrd> Node<T> {
    fn new(key: T) -> Self {
        Node {
            key,
            parent: Weak::new(),
            left: None,
            right: None,
        }
    }

    fn to_ascii_tree(&self) -> Tree {
        let left_tree = self.left.as_ref().map(|node| node.borrow().to_ascii_tree());
        let right_tree = self.right.as_ref().map(|node| node.borrow().to_ascii_tree());
        
        let mut children = Vec::new();
        if left_tree.is_some() {
            children.push(left_tree.unwrap());
        }
        if right_tree.is_some() {
            children.push(right_tree.unwrap());
        }
        
        Tree::Node(self.key.to_string(), children)
    }
}

impl<T: Display + PartialOrd> BinaryTree<T> {
    pub fn empty() -> Self {
        BinaryTree {
            root: None,
        }
    }

    pub fn new(root: Node<T>) -> Self {
        BinaryTree {
            root: Some(Rc::new(RefCell::new(root))),
        }
    }

    // pub fn insert(&mut self, k: T) {
    //     let mut new_node = Rc::new(RefCell::new(Node::new(k)));

    //     match self.root.as_ref() {
    //         None => {
    //             self.root  = Some(new_node);
    //         }
    //         Some(_) => {
    //             let mut cursor = &self.root;
    //             let mut parent = &None;
        
    //             while let Some(node) = cursor.as_ref() {
    //                 parent = cursor;

    //                 if new_node.key < node.key {
    //                     cursor = &node.left;
    //                 } else {
    //                     cursor = &node.right;
    //                 }
    //             }

    //             if let Some(parent_rc) = parent.as_ref() {
    //                 new_node.parent = Rc::downgrade(parent_rc);
    //                 if new_node.key < parent_rc.key {
    //                     parent_rc.left = Some(new_node);
    //                 } else {
    //                     parent_rc.right = Some(new_node);
    //                 }
    //             } else {
    //                 panic!("none parent");
    //             }
                
    //         }
    //     }
        
    // }

    pub fn walk(&self) {
        fn link_walk<T: Display + PartialOrd>(link: &Link<T>) {
            if let Some(node) = link.as_ref() {
                link_walk(&node.borrow().left);
                println!("{}", node.borrow().key);
                link_walk(&node.borrow().right);
            }
        }

        link_walk(&self.root);
    }

    pub fn search(&self, k: T) -> Option<Ref<Node<T>>> {
        fn search_link<T: Display + PartialOrd>(link: &Link<T>, k: T) -> Option<Ref<Node<T>>> {
            if let Some(node) = link.as_ref() {
                if k == node.borrow().key {
                    return Some(node.borrow());
                } else if k < node.borrow().key {
                    return search_link(&node.borrow().left, k);
                } else {
                    return search_link(&node.borrow().right, k);
                }
            } else {
                return None;
            }
        }

        search_link(&self.root, k)
    }

    pub fn search_iter(&self, k: T) -> Option<Ref<Node<T>>> {
        let mut cursor = &self.root;
        while let Some(node) = cursor.as_ref() {
            if k == node.borrow().key {
                return Some(node.borrow());
            } else if k < node.borrow().key {
                cursor = &node.borrow().left;
            } else {
                cursor = &node.borrow().right;
            }
        }

        return None;
    }

    pub fn minimum(&self) -> Option<Ref<Node<T>>> {
        let mut cursor = &self.root;

        while let Some(node) = cursor.as_ref() {
            cursor = &node.borrow().left;
        }

        cursor.as_ref().map(|node| node.borrow())
    }

    pub fn maximum(&self) -> Option<Ref<Node<T>>>  {
        let mut cursor = &self.root;

        while let Some(node) = cursor.as_ref() {
            cursor = &node.borrow().right;
        }

        cursor.as_ref().map(|node| node.borrow())
    }

    pub fn print(&self) {
        let none_node = Tree::Leaf(vec![String::from("none")]);
        let ascii_tree = self.root.as_ref().map_or(none_node, |node| node.borrow().to_ascii_tree());
        let mut output = String::new();
        write_tree(&mut output, &ascii_tree);
        println!("{}", output);
    }
}
// Out:
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  113 │                     return search_link(&node.borrow().left, k);
//      │                            ─────────────────┬─┬───────────────
//      │                                             ╰─────────────────── returns a value referencing data owned by the current function
//      │                                               │
//      │                                               ╰───────────────── temporary value created here
// ─────╯
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  115 │                     return search_link(&node.borrow().right, k);
//      │                            ──────────────────┬┬────────────────
//      │                                              ╰─────────────────── returns a value referencing data owned by the current function
//      │                                               │
//      │                                               ╰────────────────── temporary value created here
// ─────╯
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  129 │                 return Some(node.borrow());
//      │                        ─────────┬─────────
//      │                                 ╰─────────── returns a value referencing data owned by the current function
//      │
//  133 │                 cursor = &node.borrow().right;
//      │                           ──────┬──────
//      │                                 ╰──────── temporary value created here
// ─────╯
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  129 │                 return Some(node.borrow());
//      │                        ─────────┬─────────
//      │                                 ╰─────────── returns a value referencing data owned by the current function
//      │
//  131 │                 cursor = &node.borrow().left;
//      │                           ──────┬──────
//      │                                 ╰──────── temporary value created here
// ─────╯
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  144 │             cursor = &node.borrow().left;
//      │                       ──────┬──────
//      │                             ╰──────── temporary value created here
//      │
//  147 │         cursor.as_ref().map(|node| node.borrow())
//      │         ────────────────────┬────────────────────
//      │                             ╰────────────────────── returns a value referencing data owned by the current function
// ─────╯
// [E0515] Error: cannot return value referencing temporary value
//      ╭─[command_3:1:1]
//      │
//  154 │             cursor = &node.borrow().right;
//      │                       ──────┬──────
//      │                             ╰──────── temporary value created here
//      │
//  157 │         cursor.as_ref().map(|node| node.borrow())
//      │         ────────────────────┬────────────────────
//      │                             ╰────────────────────── returns a value referencing data owned by the current function
// ─────╯
