// %%
:dep ascii_tree = {version = "0.1.1"}

// %%
use std::fmt::Display;
use std::rc::{Rc, Weak};
use std::cell::{RefCell, Ref};
use ascii_tree::{Tree, write_tree}

pub struct BinaryTree<T> {
    root: Link<T>,
}

type Link<T> = Option<Box<Node<T>>>;

pub struct Node<T> {
    key: T,
    parent: Option<&'_ Box<Node<T>>>,
    left: Link<T>,
    right: Link<T>,
}

impl<T> Node<T> {
    fn new(key: T) -> Self {
        Node {
            key,
            parent: None,
            left: None,
            right: None,
        }
    }

    fn to_ascii_tree(&self) -> Tree {
        let left_tree = self.left.as_ref().map(|node| node.to_ascii_tree());
        let right_tree = self.right.as_ref().map(|node| node.to_ascii_tree());
        
        let mut children = Vec::new();
        if left_tree.is_some() {
            children.push(left_tree.unwrap());
        }
        if right_tree.is_some() {
            children.push(right_tree.unwrap());
        }
        
        Tree::Node(self.key.to_string(), children)
    }
}

impl<T: Display + PartialOrd> BinaryTree<T> {
    pub fn empty() -> Self {
        BinaryTree {
            root: None,
        }
    }

    pub fn new(root: Node<T>) -> Self {
        BinaryTree {
            root: Some(Box::new(root)),
        }
    }

    pub fn insert(&mut self, k: T) {
        let mut new_node = Box::new(Node::new(k));

        let mut cursor: Option<&Box<Node<T>>> = self.root.as_ref();
        let mut parent: Option<&Box<Node<T>>> = None;

        while Some(cursor_node) = cursor {
            parent = cursor;

            if new_node.key < cursor_node.key {
                cursor = cursor_node.left.as_ref();
            } else {
                cursor = cursor_node.right.as_ref();
            }
        }

        if let Some(parent_node) = parent {
            new_node.parent = parent;
            if new_node.key < parent_node.key {
                parent_node.left = Some(new_node);
            } else {
                parent_node.right = Some(new_node);
            }
        } else {
            self.root  = Some(new_node);
        }
    
    }

    pub fn walk(&self) {
        fn link_walk<T: Display + PartialOrd>(link: &Link<T>) {
            if let Some(node) = link.as_ref() {
                link_walk(&node.left);
                println!("{}", node.key);
                link_walk(&node.right);
            }
        }

        link_walk(&self.root);
    }

    // pub fn search(&self, k: T) -> Option<Ref<Node<T>>> {
    //     fn search_link<T: Display + PartialOrd>(link: Option<Ref<Node<T>>>, k: T) -> Option<Ref<Node<T>>> {
    //         if let Some(node) = link.as_ref() {
    //             if k == node.borrow().key {
    //                 return Some(node.borrow());
    //             } else if k < node.borrow().key {
    //                 return search_link(node.borrow().map(|link| link.left, k);
    //             } else {
    //                 return search_link(node.borrow().right, k);
    //             }
    //         } else {
    //             return None;
    //         }
    //     }

    //     search_link(self.root.map(|link| link.borrow(), k)
    // }

    // pub fn search_iter(&self, k: T) -> Option<Ref<Node<T>>> {
    //     let mut cursor = &self.root;
    //     while let Some(node) = cursor.as_ref() {
    //         if k == node.borrow().key {
    //             return Some(node.borrow());
    //         } else if k < node.borrow().key {
    //             cursor = &node.borrow().left;
    //         } else {
    //             cursor = &node.borrow().right;
    //         }
    //     }

    //     return None;
    // }

    // pub fn minimum(&self) -> Option<Ref<Node<T>>> {
    //     let mut cursor = &self.root;

    //     while let Some(node) = cursor.as_ref() {
    //         cursor = &node.borrow().left;
    //     }

    //     cursor.as_ref().map(|node| node.borrow())
    // }

    // pub fn maximum(&self) -> Option<Ref<Node<T>>>  {
    //     let mut cursor = &self.root;

    //     while let Some(node) = cursor.as_ref() {
    //         cursor = &node.borrow().right;
    //     }

    //     cursor.as_ref().map(|node| node.borrow())
    // }

    pub fn print(&self) {
        let none_node = Tree::Leaf(vec![String::from("none")]);
        let ascii_tree = self.root.as_ref().map_or(none_node, |node| node.borrow().to_ascii_tree());
        let mut output = String::new();
        write_tree(&mut output, &ascii_tree);
        println!("{}", output);
    }
}
// Out:
// [E0106] Error: missing lifetime specifier
//     ╭─[command_13:1:1]
//     │
//  14 │     parent: Option<&'_ Box<Node<T>>>,
//     │                     ─┬
//     │                      ╰── expected named lifetime parameter
// ────╯
// [E0425] Error: cannot find value `cursor_node` in this scope
//     ╭─[command_13:1:1]
//     │
//  64 │         while Some(cursor_node) = cursor {
//     │               │    ─────┬─────
//     │               ╰───────────────── help: you might have meant to use pattern matching: `let `
//     │                         │
//     │                         ╰─────── not found in this scope
// ────╯
// [E0425] Error: cannot find value `cursor_node` in this scope
//     ╭─[command_13:1:1]
//     │
//  67 │             if new_node.key < cursor_node.key {
//     │                               ─────┬─────
//     │                                    ╰─────── not found in this scope
// ────╯
// [E0425] Error: cannot find value `cursor_node` in this scope
//     ╭─[command_13:1:1]
//     │
//  68 │                 cursor = cursor_node.left.as_ref();
//     │                          ─────┬─────
//     │                               ╰─────── not found in this scope
// ────╯
// [E0425] Error: cannot find value `cursor_node` in this scope
//     ╭─[command_13:1:1]
//     │
//  70 │                 cursor = cursor_node.right.as_ref();
//     │                          ─────┬─────
//     │                               ╰─────── not found in this scope
// ────╯
// [E0599] Error: the method `map` exists for enum `Option<&Box<Node<T>>>`, but its trait bounds were not satisfied
//     ╭─[command_13:1:1]
//     │
//  30 │         let left_tree = self.left.as_ref().map(|node| node.to_ascii_tree());
//     │                                            ─┬─
//     │                                             ╰─── method cannot be called on `Option<&Box<Node<T>>>` due to unsatisfied trait bounds
// ────╯
// [E0599] Error: the method `map` exists for enum `Option<&Box<Node<T>>>`, but its trait bounds were not satisfied
//     ╭─[command_13:1:1]
//     │
//  31 │         let right_tree = self.right.as_ref().map(|node| node.to_ascii_tree());
//     │                                              ─┬─
//     │                                               ╰─── method cannot be called on `Option<&Box<Node<T>>>` due to unsatisfied trait bounds
// ────╯
// [E0599] Error: no method named `to_string` found for type parameter `T` in the current scope
//     ╭─[command_13:1:1]
//     │
//  19 │ impl<T> Node<T> {
//     │      ┬│
//     │      ╰── method `to_string` not found for this type parameter
//     │       │
//     │       ╰─ help: the following trait defines an item `to_string`, perhaps you need to restrict type parameter `T` with it:: `: ToString`
//     │
//  41 │         Tree::Node(self.key.to_string(), children)
//     │                             ────┬────
//     │                                 ╰────── method cannot be called on `T` due to unsatisfied trait bounds
// ────╯
// [E0599] Error: no method named `borrow` found for reference `&Box<Node<T>>` in the current scope
//      ╭─[command_13:1:1]
//      │
//   12 │ pub struct Node<T> {
//      │ │
//      │ ╰─ help: trait `Borrow` which provides `borrow` is implemented but not in scope; perhaps you want to import it: `use std::borrow::Borrow;
// `
//      │
//  154 │         let ascii_tree = self.root.as_ref().map_or(none_node, |node| node.borrow().to_ascii_tree());
//      │                                                                           ───┬──
//      │                                                                              ╰──── error: no method named `borrow` found for reference `&Box<Node<T>>` in the current scope
//      │                                                                              │
//      │                                                                              ╰──── help: there is a method `borrow_mut` with a similar name: `borrow_mut`
// ─────╯
